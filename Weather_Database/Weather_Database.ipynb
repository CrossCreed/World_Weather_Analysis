# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
# Create a new set of 2,000 random latitudes and longitudes.
latitudes = np.random.uniform(low=-90.000, high=90.000, size=2000)
longitudes = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(latitudes, longitudes)

# %%
# Get the nearest city using the citipy module.
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 782

# %%
# Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

    # Run an API request for each of the cities.
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        # Append the city information into city_data list.
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
        
    # If an error is experienced, skip the city.    
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sao filipe
# Processing Record 2 of Set 1 | nanortalik
# Processing Record 3 of Set 1 | souillac
# Processing Record 4 of Set 1 | hasaki
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | mosetse
# Processing Record 7 of Set 1 | pevek
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | ostrovnoy
# Processing Record 10 of Set 1 | kloulklubed
# Processing Record 11 of Set 1 | reconquista
# Processing Record 12 of Set 1 | palauig
# Processing Record 13 of Set 1 | dubbo
# Processing Record 14 of Set 1 | khatanga
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | carutapera
# Processing Record 17 of Set 1 | torbay
# Processing Record 18 of Set 1 | benton
# Processing Record 19 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 1 | magan
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | arroyo
# Processing Record 28 of Set 1 | cidreira
# Processing Record 29 of Set 1 | dikson
# Processing Record 30 of Set 1 | cabo san lucas
# Processing Record 31 of Set 1 | dauriya
# Processing Record 32 of Set 1 | ketchikan
# Processing Record 33 of Set 1 | cayenne
# Processing Record 34 of Set 1 | sungaipenuh
# Processing Record 35 of Set 1 | san ignacio
# Processing Record 36 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 1 | harlingen
# Processing Record 38 of Set 1 | saint andrews
# Processing Record 39 of Set 1 | east london
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 42 of Set 1 | bambous virieux
# Processing Record 43 of Set 1 | nemuro
# Processing Record 44 of Set 1 | fortuna
# Processing Record 45 of Set 1 | arraial do cabo
# Processing Record 46 of Set 1 | narsaq
# Processing Record 47 of Set 1 | saint simons
# Processing Record 48 of Set 1 | hervey bay
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | tuktoyaktuk
# Processing Record 1 of Set 2 | ahuimanu
# Processing Record 2 of Set 2 | barrow
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | husavik
# Processing Record 5 of Set 2 | hermanus
# Processing Record 6 of Set 2 | kiama
# Processing Record 7 of Set 2 | stolin
# Processing Record 8 of Set 2 | haysville
# Processing Record 9 of Set 2 | ponta do sol
# Processing Record 10 of Set 2 | san patricio
# Processing Record 11 of Set 2 | inderborskiy
# City not found. Skipping...
# Processing Record 12 of Set 2 | saint-augustin
# Processing Record 13 of Set 2 | mecca
# Processing Record 14 of Set 2 | port alfred
# Processing Record 15 of Set 2 | coahuayana
# Processing Record 16 of Set 2 | paamiut
# Processing Record 17 of Set 2 | nadym
# Processing Record 18 of Set 2 | truth or consequences
# Processing Record 19 of Set 2 | atuona
# Processing Record 20 of Set 2 | nikolskoye
# Processing Record 21 of Set 2 | carnarvon
# Processing Record 22 of Set 2 | luderitz
# Processing Record 23 of Set 2 | upernavik
# Processing Record 24 of Set 2 | tiksi
# Processing Record 25 of Set 2 | saint-philippe
# Processing Record 26 of Set 2 | charlottetown
# Processing Record 27 of Set 2 | castro
# Processing Record 28 of Set 2 | klyuchi
# Processing Record 29 of Set 2 | havelock
# Processing Record 30 of Set 2 | beloha
# Processing Record 31 of Set 2 | saint george
# Processing Record 32 of Set 2 | qabis
# City not found. Skipping...
# Processing Record 33 of Set 2 | bengkulu
# Processing Record 34 of Set 2 | busselton
# Processing Record 35 of Set 2 | port elizabeth
# Processing Record 36 of Set 2 | uppsala
# Processing Record 37 of Set 2 | berlevag
# Processing Record 38 of Set 2 | biskupiec
# Processing Record 39 of Set 2 | copiapo
# Processing Record 40 of Set 2 | hilo
# Processing Record 41 of Set 2 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 42 of Set 2 | broome
# Processing Record 43 of Set 2 | tuatapere
# Processing Record 44 of Set 2 | matara
# Processing Record 45 of Set 2 | istmina
# Processing Record 46 of Set 2 | beringovskiy
# Processing Record 47 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 48 of Set 2 | wynyard
# Processing Record 49 of Set 2 | severo-kurilsk
# Processing Record 50 of Set 2 | falkoping
# City not found. Skipping...
# Processing Record 1 of Set 3 | richards bay
# Processing Record 2 of Set 3 | bairiki
# Processing Record 3 of Set 3 | sinnamary
# Processing Record 4 of Set 3 | kyabe
# Processing Record 5 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 3 | keflavik
# Processing Record 7 of Set 3 | altona
# Processing Record 8 of Set 3 | katangli
# Processing Record 9 of Set 3 | hobart
# Processing Record 10 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 3 | ushuaia
# Processing Record 12 of Set 3 | mount isa
# Processing Record 13 of Set 3 | geraldton
# Processing Record 14 of Set 3 | ahipara
# Processing Record 15 of Set 3 | sterling
# Processing Record 16 of Set 3 | moroni
# Processing Record 17 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 18 of Set 3 | kitimat
# Processing Record 19 of Set 3 | santa isabel do rio negro
# Processing Record 20 of Set 3 | kaitangata
# Processing Record 21 of Set 3 | axim
# Processing Record 22 of Set 3 | lencois paulista
# Processing Record 23 of Set 3 | barcea
# Processing Record 24 of Set 3 | airai
# Processing Record 25 of Set 3 | fare
# Processing Record 26 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 3 | leningradskiy
# Processing Record 28 of Set 3 | mapiripan
# Processing Record 29 of Set 3 | russell
# Processing Record 30 of Set 3 | esperance
# Processing Record 31 of Set 3 | cartagena
# Processing Record 32 of Set 3 | lompoc
# Processing Record 33 of Set 3 | vanimo
# Processing Record 34 of Set 3 | jamestown
# Processing Record 35 of Set 3 | providencia
# Processing Record 36 of Set 3 | sena madureira
# Processing Record 37 of Set 3 | maua
# Processing Record 38 of Set 3 | marietta
# Processing Record 39 of Set 3 | navalmoral de la mata
# Processing Record 40 of Set 3 | kailua
# Processing Record 41 of Set 3 | fukue
# Processing Record 42 of Set 3 | hithadhoo
# Processing Record 43 of Set 3 | vredendal
# Processing Record 44 of Set 3 | hastings
# Processing Record 45 of Set 3 | abu dhabi
# Processing Record 46 of Set 3 | cabedelo
# Processing Record 47 of Set 3 | ous
# Processing Record 48 of Set 3 | qaanaaq
# Processing Record 49 of Set 3 | guerrero negro
# Processing Record 50 of Set 3 | ambilobe
# Processing Record 1 of Set 4 | manta
# Processing Record 2 of Set 4 | ramygala
# Processing Record 3 of Set 4 | lufilufi
# Processing Record 4 of Set 4 | sitka
# Processing Record 5 of Set 4 | ancud
# Processing Record 6 of Set 4 | sergeyevka
# Processing Record 7 of Set 4 | kachiry
# Processing Record 8 of Set 4 | derzhavinsk
# Processing Record 9 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 4 | poum
# Processing Record 11 of Set 4 | batagay
# Processing Record 12 of Set 4 | bredasdorp
# Processing Record 13 of Set 4 | aklavik
# Processing Record 14 of Set 4 | vardo
# Processing Record 15 of Set 4 | cherskiy
# Processing Record 16 of Set 4 | morant bay
# Processing Record 17 of Set 4 | atambua
# Processing Record 18 of Set 4 | mazagao
# Processing Record 19 of Set 4 | pilar
# Processing Record 20 of Set 4 | mus
# Processing Record 21 of Set 4 | birjand
# Processing Record 22 of Set 4 | avarua
# Processing Record 23 of Set 4 | hofn
# Processing Record 24 of Set 4 | san isidro
# Processing Record 25 of Set 4 | ribeira grande
# Processing Record 26 of Set 4 | sobolevo
# Processing Record 27 of Set 4 | dalinghe
# City not found. Skipping...
# Processing Record 28 of Set 4 | mahajanga
# Processing Record 29 of Set 4 | kiruna
# Processing Record 30 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 4 | dingle
# Processing Record 32 of Set 4 | zhaotong
# Processing Record 33 of Set 4 | waingapu
# Processing Record 34 of Set 4 | samarai
# Processing Record 35 of Set 4 | dukat
# Processing Record 36 of Set 4 | chuy
# Processing Record 37 of Set 4 | paita
# Processing Record 38 of Set 4 | bosobolo
# Processing Record 39 of Set 4 | mount gambier
# Processing Record 40 of Set 4 | saint-pierre
# Processing Record 41 of Set 4 | cobija
# Processing Record 42 of Set 4 | ixtapa
# Processing Record 43 of Set 4 | norman wells
# Processing Record 44 of Set 4 | asyut
# Processing Record 45 of Set 4 | kavieng
# Processing Record 46 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 4 | rio grande
# Processing Record 48 of Set 4 | luanda
# Processing Record 49 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 4 | thompson
# Processing Record 1 of Set 5 | oistins
# Processing Record 2 of Set 5 | victoria
# Processing Record 3 of Set 5 | rocha
# Processing Record 4 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 6 of Set 5 | tavda
# Processing Record 7 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 8 of Set 5 | bilma
# Processing Record 9 of Set 5 | padang
# Processing Record 10 of Set 5 | caravelas
# Processing Record 11 of Set 5 | sola
# Processing Record 12 of Set 5 | teya
# Processing Record 13 of Set 5 | saldanha
# Processing Record 14 of Set 5 | port hawkesbury
# Processing Record 15 of Set 5 | bartica
# Processing Record 16 of Set 5 | gat
# Processing Record 17 of Set 5 | ucluelet
# Processing Record 18 of Set 5 | cherdyn
# Processing Record 19 of Set 5 | saskylakh
# Processing Record 20 of Set 5 | basco
# Processing Record 21 of Set 5 | koutiala
# Processing Record 22 of Set 5 | gannan
# Processing Record 23 of Set 5 | clyde river
# Processing Record 24 of Set 5 | almaznyy
# Processing Record 25 of Set 5 | zhigansk
# Processing Record 26 of Set 5 | diffa
# Processing Record 27 of Set 5 | kisiwani
# Processing Record 28 of Set 5 | la primavera
# Processing Record 29 of Set 5 | georgetown
# Processing Record 30 of Set 5 | aykhal
# Processing Record 31 of Set 5 | daru
# Processing Record 32 of Set 5 | popondetta
# Processing Record 33 of Set 5 | chimore
# Processing Record 34 of Set 5 | lake havasu city
# Processing Record 35 of Set 5 | baracoa
# Processing Record 36 of Set 5 | tezu
# Processing Record 37 of Set 5 | chokurdakh
# Processing Record 38 of Set 5 | kavaratti
# Processing Record 39 of Set 5 | acapulco
# Processing Record 40 of Set 5 | ouesso
# Processing Record 41 of Set 5 | zhuhai
# Processing Record 42 of Set 5 | buta
# Processing Record 43 of Set 5 | washington
# Processing Record 44 of Set 5 | sosnogorsk
# Processing Record 45 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 5 | alekseyevka
# Processing Record 47 of Set 5 | benguela
# Processing Record 48 of Set 5 | marsaxlokk
# Processing Record 49 of Set 5 | harper
# Processing Record 50 of Set 5 | khipro
# Processing Record 1 of Set 6 | kieta
# Processing Record 2 of Set 6 | tasiilaq
# Processing Record 3 of Set 6 | ayabaca
# Processing Record 4 of Set 6 | lima
# Processing Record 5 of Set 6 | candido de abreu
# Processing Record 6 of Set 6 | clinton
# Processing Record 7 of Set 6 | shetpe
# Processing Record 8 of Set 6 | san cristobal
# Processing Record 9 of Set 6 | ponte de sor
# Processing Record 10 of Set 6 | husum
# Processing Record 11 of Set 6 | ahar
# Processing Record 12 of Set 6 | longyearbyen
# Processing Record 13 of Set 6 | naze
# Processing Record 14 of Set 6 | port blair
# Processing Record 15 of Set 6 | cockburn town
# Processing Record 16 of Set 6 | sawtell
# Processing Record 17 of Set 6 | beboto
# Processing Record 18 of Set 6 | constitucion
# Processing Record 19 of Set 6 | eldorado
# Processing Record 20 of Set 6 | passo de camaragibe
# Processing Record 21 of Set 6 | mimongo
# Processing Record 22 of Set 6 | flin flon
# Processing Record 23 of Set 6 | el balyana
# City not found. Skipping...
# Processing Record 24 of Set 6 | olafsvik
# Processing Record 25 of Set 6 | la ronge
# Processing Record 26 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 27 of Set 6 | gorontalo
# Processing Record 28 of Set 6 | khani
# Processing Record 29 of Set 6 | margate
# Processing Record 30 of Set 6 | haines junction
# Processing Record 31 of Set 6 | severo-yeniseyskiy
# Processing Record 32 of Set 6 | hamilton
# Processing Record 33 of Set 6 | tahta
# Processing Record 34 of Set 6 | tete
# Processing Record 35 of Set 6 | hagere hiywet
# Processing Record 36 of Set 6 | lebu
# Processing Record 37 of Set 6 | namatanai
# Processing Record 38 of Set 6 | turan
# Processing Record 39 of Set 6 | mahebourg
# Processing Record 40 of Set 6 | antofagasta
# Processing Record 41 of Set 6 | puri
# Processing Record 42 of Set 6 | road town
# Processing Record 43 of Set 6 | new norfolk
# Processing Record 44 of Set 6 | abu samrah
# Processing Record 45 of Set 6 | faya
# Processing Record 46 of Set 6 | iqaluit
# Processing Record 47 of Set 6 | santander
# Processing Record 48 of Set 6 | novyye burasy
# Processing Record 49 of Set 6 | aksu
# Processing Record 50 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 7 | san quintin
# Processing Record 2 of Set 7 | atar
# Processing Record 3 of Set 7 | excelsior springs
# Processing Record 4 of Set 7 | marsa matruh
# Processing Record 5 of Set 7 | paragominas
# Processing Record 6 of Set 7 | alofi
# Processing Record 7 of Set 7 | murgab
# Processing Record 8 of Set 7 | longyan
# Processing Record 9 of Set 7 | bandarbeyla
# Processing Record 10 of Set 7 | lagoa
# Processing Record 11 of Set 7 | flagstaff
# Processing Record 12 of Set 7 | copperas cove
# Processing Record 13 of Set 7 | qasigiannguit
# Processing Record 14 of Set 7 | kodiak
# Processing Record 15 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 7 | talakan
# Processing Record 17 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 7 | catuday
# Processing Record 19 of Set 7 | pocone
# Processing Record 20 of Set 7 | sandy bay
# Processing Record 21 of Set 7 | abeche
# Processing Record 22 of Set 7 | los llanos de aridane
# Processing Record 23 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 24 of Set 7 | fort walton beach
# Processing Record 25 of Set 7 | kyshtovka
# Processing Record 26 of Set 7 | mao
# Processing Record 27 of Set 7 | tanggulangin
# Processing Record 28 of Set 7 | tracy
# Processing Record 29 of Set 7 | launceston
# Processing Record 30 of Set 7 | camacha
# Processing Record 31 of Set 7 | ayan
# Processing Record 32 of Set 7 | pitimbu
# Processing Record 33 of Set 7 | dolores
# Processing Record 34 of Set 7 | lata
# Processing Record 35 of Set 7 | butaritari
# Processing Record 36 of Set 7 | alta floresta
# Processing Record 37 of Set 7 | talnakh
# Processing Record 38 of Set 7 | tucuman
# Processing Record 39 of Set 7 | batagay-alyta
# Processing Record 40 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 7 | corpus christi
# Processing Record 42 of Set 7 | nova olimpia
# Processing Record 43 of Set 7 | fairmont
# Processing Record 44 of Set 7 | aras
# Processing Record 45 of Set 7 | zenzeli
# Processing Record 46 of Set 7 | strezhevoy
# Processing Record 47 of Set 7 | mizdah
# Processing Record 48 of Set 7 | pucallpa
# Processing Record 49 of Set 7 | lac-megantic
# Processing Record 50 of Set 7 | ulaangom
# Processing Record 1 of Set 8 | el alto
# Processing Record 2 of Set 8 | buala
# Processing Record 3 of Set 8 | thinadhoo
# Processing Record 4 of Set 8 | kuytun
# Processing Record 5 of Set 8 | tautira
# Processing Record 6 of Set 8 | lincoln
# Processing Record 7 of Set 8 | camocim
# Processing Record 8 of Set 8 | vanavara
# Processing Record 9 of Set 8 | lysa nad labem
# Processing Record 10 of Set 8 | pozo colorado
# Processing Record 11 of Set 8 | tungkang
# City not found. Skipping...
# Processing Record 12 of Set 8 | mezen
# Processing Record 13 of Set 8 | namibe
# Processing Record 14 of Set 8 | katima mulilo
# Processing Record 15 of Set 8 | salaga
# Processing Record 16 of Set 8 | santa cruz
# Processing Record 17 of Set 8 | hovd
# Processing Record 18 of Set 8 | maroantsetra
# Processing Record 19 of Set 8 | tando jam
# Processing Record 20 of Set 8 | kruisfontein
# Processing Record 21 of Set 8 | todos santos
# Processing Record 22 of Set 8 | sakakah
# Processing Record 23 of Set 8 | sangar
# Processing Record 24 of Set 8 | yellowknife
# Processing Record 25 of Set 8 | paka
# Processing Record 26 of Set 8 | ayr
# Processing Record 27 of Set 8 | pontianak
# Processing Record 28 of Set 8 | belaya gora
# Processing Record 29 of Set 8 | rawson
# Processing Record 30 of Set 8 | tambul
# City not found. Skipping...
# Processing Record 31 of Set 8 | rongcheng
# Processing Record 32 of Set 8 | tual
# Processing Record 33 of Set 8 | jakarta
# Processing Record 34 of Set 8 | puerto del rosario
# Processing Record 35 of Set 8 | komsomolskiy
# Processing Record 36 of Set 8 | marzuq
# Processing Record 37 of Set 8 | kuliyapitiya
# Processing Record 38 of Set 8 | codrington
# Processing Record 39 of Set 8 | billings
# Processing Record 40 of Set 8 | baruun-urt
# Processing Record 41 of Set 8 | kinsale
# Processing Record 42 of Set 8 | garoua
# Processing Record 43 of Set 8 | svetlyy
# Processing Record 44 of Set 8 | lasa
# Processing Record 45 of Set 8 | iskateley
# Processing Record 46 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 47 of Set 8 | muzhi
# Processing Record 48 of Set 8 | san
# Processing Record 49 of Set 8 | poarta alba
# Processing Record 50 of Set 8 | pyapon
# Processing Record 1 of Set 9 | korla
# Processing Record 2 of Set 9 | lavrentiya
# Processing Record 3 of Set 9 | adre
# Processing Record 4 of Set 9 | port lincoln
# Processing Record 5 of Set 9 | kerema
# Processing Record 6 of Set 9 | benghazi
# Processing Record 7 of Set 9 | villerupt
# Processing Record 8 of Set 9 | nouakchott
# Processing Record 9 of Set 9 | mar del plata
# Processing Record 10 of Set 9 | xinyu
# Processing Record 11 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 9 | taitung
# Processing Record 13 of Set 9 | montrose
# Processing Record 14 of Set 9 | yabrud
# Processing Record 15 of Set 9 | dharchula
# Processing Record 16 of Set 9 | luangwa
# Processing Record 17 of Set 9 | neyshabur
# Processing Record 18 of Set 9 | zdvinsk
# Processing Record 19 of Set 9 | yeppoon
# Processing Record 20 of Set 9 | bonfim
# Processing Record 21 of Set 9 | hendijan
# City not found. Skipping...
# Processing Record 22 of Set 9 | touros
# Processing Record 23 of Set 9 | chatellerault
# Processing Record 24 of Set 9 | ikom
# Processing Record 25 of Set 9 | zaragoza
# Processing Record 26 of Set 9 | salgueiro
# Processing Record 27 of Set 9 | rafaela
# Processing Record 28 of Set 9 | clarence town
# Processing Record 29 of Set 9 | saint-georges
# Processing Record 30 of Set 9 | comodoro rivadavia
# Processing Record 31 of Set 9 | linxia
# Processing Record 32 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 9 | camana
# Processing Record 34 of Set 9 | presidente medici
# Processing Record 35 of Set 9 | marawi
# Processing Record 36 of Set 9 | thiruvananthapuram
# Processing Record 37 of Set 9 | necochea
# Processing Record 38 of Set 9 | tevaitoa
# Processing Record 39 of Set 9 | makubetsu
# Processing Record 40 of Set 9 | ilulissat
# Processing Record 41 of Set 9 | camrose
# Processing Record 42 of Set 9 | fairbanks
# Processing Record 43 of Set 9 | ballina
# Processing Record 44 of Set 9 | huinan
# Processing Record 45 of Set 9 | noumea
# Processing Record 46 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 47 of Set 9 | bonthe
# Processing Record 48 of Set 9 | penzance
# Processing Record 49 of Set 9 | bethel
# Processing Record 50 of Set 9 | batemans bay
# Processing Record 1 of Set 10 | terre-de-bas
# Processing Record 2 of Set 10 | chowchilla
# Processing Record 3 of Set 10 | provideniya
# Processing Record 4 of Set 10 | talcahuano
# Processing Record 5 of Set 10 | karanpura
# Processing Record 6 of Set 10 | lorengau
# Processing Record 7 of Set 10 | tessalit
# Processing Record 8 of Set 10 | goderich
# Processing Record 9 of Set 10 | riviere-au-renard
# Processing Record 10 of Set 10 | kardla
# Processing Record 11 of Set 10 | iberia
# Processing Record 12 of Set 10 | toritama
# Processing Record 13 of Set 10 | miranda
# Processing Record 14 of Set 10 | mwinilunga
# Processing Record 15 of Set 10 | hami
# Processing Record 16 of Set 10 | srednekolymsk
# Processing Record 17 of Set 10 | doha
# Processing Record 18 of Set 10 | belgrade
# Processing Record 19 of Set 10 | pangnirtung
# Processing Record 20 of Set 10 | pisco
# Processing Record 21 of Set 10 | hachinohe
# Processing Record 22 of Set 10 | bud
# Processing Record 23 of Set 10 | praia da vitoria
# Processing Record 24 of Set 10 | trairi
# Processing Record 25 of Set 10 | numan
# Processing Record 26 of Set 10 | tabou
# Processing Record 27 of Set 10 | oranjestad
# Processing Record 28 of Set 10 | nome
# Processing Record 29 of Set 10 | gouyave
# Processing Record 30 of Set 10 | mbarara
# Processing Record 31 of Set 10 | sisimiut
# Processing Record 32 of Set 10 | zhanatas
# City not found. Skipping...
# Processing Record 33 of Set 10 | fort nelson
# Processing Record 34 of Set 10 | panzhihua
# Processing Record 35 of Set 10 | vera cruz
# Processing Record 36 of Set 10 | walvis bay
# Processing Record 37 of Set 10 | brigantine
# Processing Record 38 of Set 10 | thai binh
# Processing Record 39 of Set 10 | sechura
# Processing Record 40 of Set 10 | loa janan
# Processing Record 41 of Set 10 | kutum
# Processing Record 42 of Set 10 | te anau
# Processing Record 43 of Set 10 | makakilo city
# Processing Record 44 of Set 10 | carikar
# City not found. Skipping...
# Processing Record 45 of Set 10 | san rafael
# Processing Record 46 of Set 10 | shimoda
# Processing Record 47 of Set 10 | port hardy
# Processing Record 48 of Set 10 | blackwater
# Processing Record 49 of Set 10 | bayanday
# Processing Record 50 of Set 10 | bontang
# Processing Record 1 of Set 11 | deputatskiy
# Processing Record 2 of Set 11 | alice springs
# Processing Record 3 of Set 11 | tlapehuala
# Processing Record 4 of Set 11 | isiro
# Processing Record 5 of Set 11 | kalmunai
# Processing Record 6 of Set 11 | abhar
# Processing Record 7 of Set 11 | hambantota
# Processing Record 8 of Set 11 | port-gentil
# Processing Record 9 of Set 11 | voghera
# Processing Record 10 of Set 11 | ouango
# Processing Record 11 of Set 11 | muros
# Processing Record 12 of Set 11 | casablanca
# Processing Record 13 of Set 11 | oussouye
# Processing Record 14 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 11 | joinville
# Processing Record 16 of Set 11 | sijunjung
# Processing Record 17 of Set 11 | petersburg
# Processing Record 18 of Set 11 | banjar
# Processing Record 19 of Set 11 | kayan
# Processing Record 20 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 21 of Set 11 | sinjar
# Processing Record 22 of Set 11 | shuangyang
# Processing Record 23 of Set 11 | tawzar
# City not found. Skipping...
# Processing Record 24 of Set 11 | aligudarz
# Processing Record 25 of Set 11 | luau
# Processing Record 26 of Set 11 | manaure
# Processing Record 27 of Set 11 | menongue
# Processing Record 28 of Set 11 | independence
# Processing Record 29 of Set 11 | zyryanskoye
# Processing Record 30 of Set 11 | oxford
# Processing Record 31 of Set 11 | umm kaddadah
# Processing Record 32 of Set 11 | gigmoto
# Processing Record 33 of Set 11 | meadow lake
# Processing Record 34 of Set 11 | huanren
# Processing Record 35 of Set 11 | roquetas de mar
# Processing Record 36 of Set 11 | laguna
# Processing Record 37 of Set 11 | levelland
# Processing Record 38 of Set 11 | tigre
# Processing Record 39 of Set 11 | vila velha
# Processing Record 40 of Set 11 | puerto escondido
# Processing Record 41 of Set 11 | wadi maliz
# Processing Record 42 of Set 11 | gambela
# Processing Record 43 of Set 11 | warora
# Processing Record 44 of Set 11 | laukaa
# Processing Record 45 of Set 11 | boddam
# Processing Record 46 of Set 11 | yaypan
# Processing Record 47 of Set 11 | mareeba
# Processing Record 48 of Set 11 | dong hoi
# Processing Record 49 of Set 11 | hue
# Processing Record 50 of Set 11 | la sarre
# Processing Record 1 of Set 12 | izhma
# Processing Record 2 of Set 12 | la paz
# Processing Record 3 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 4 of Set 12 | fiumicino
# Processing Record 5 of Set 12 | sohbatpur
# Processing Record 6 of Set 12 | port augusta
# Processing Record 7 of Set 12 | bathsheba
# Processing Record 8 of Set 12 | glendive
# Processing Record 9 of Set 12 | leh
# Processing Record 10 of Set 12 | turukhansk
# Processing Record 11 of Set 12 | udachnyy
# Processing Record 12 of Set 12 | biggar
# Processing Record 13 of Set 12 | bermejo
# Processing Record 14 of Set 12 | grozesti
# Processing Record 15 of Set 12 | ukiah
# Processing Record 16 of Set 12 | barra patuca
# Processing Record 17 of Set 12 | belyy yar
# Processing Record 18 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 12 | lockerbie
# Processing Record 20 of Set 12 | tehuantepec
# City not found. Skipping...
# Processing Record 21 of Set 12 | bunia
# Processing Record 22 of Set 12 | parana
# Processing Record 23 of Set 12 | pudozh
# Processing Record 24 of Set 12 | mnogovershinnyy
# Processing Record 25 of Set 12 | balkhash
# Processing Record 26 of Set 12 | quang ngai
# Processing Record 27 of Set 12 | gasa
# Processing Record 28 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 29 of Set 12 | kharitonovo
# Processing Record 30 of Set 12 | dedza
# Processing Record 31 of Set 12 | putina
# Processing Record 32 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 33 of Set 12 | quimper
# Processing Record 34 of Set 12 | sayyan
# Processing Record 35 of Set 12 | ondo
# Processing Record 36 of Set 12 | olga
# Processing Record 37 of Set 12 | santa maria
# Processing Record 38 of Set 12 | vilhena
# Processing Record 39 of Set 12 | tazovskiy
# Processing Record 40 of Set 12 | djenne
# Processing Record 41 of Set 12 | dalvik
# Processing Record 42 of Set 12 | karasjok
# Processing Record 43 of Set 12 | alenquer
# Processing Record 44 of Set 12 | coquimbo
# Processing Record 45 of Set 12 | biak
# Processing Record 46 of Set 12 | namwala
# Processing Record 47 of Set 12 | cam ranh
# Processing Record 48 of Set 12 | mogok
# Processing Record 49 of Set 12 | grand gaube
# Processing Record 50 of Set 12 | pizarro
# Processing Record 1 of Set 13 | kirakira
# Processing Record 2 of Set 13 | ereymentau
# Processing Record 3 of Set 13 | homer
# Processing Record 4 of Set 13 | tirano
# Processing Record 5 of Set 13 | tashtagol
# Processing Record 6 of Set 13 | sampit
# Processing Record 7 of Set 13 | mount clemens
# Processing Record 8 of Set 13 | egvekinot
# Processing Record 9 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 10 of Set 13 | camacupa
# Processing Record 11 of Set 13 | vila franca do campo
# Processing Record 12 of Set 13 | krasnoarmeyskoye
# Processing Record 13 of Set 13 | nan
# Processing Record 14 of Set 13 | abu zabad
# Processing Record 15 of Set 13 | mutare
# Processing Record 16 of Set 13 | bereda
# Processing Record 17 of Set 13 | klaksvik
# Processing Record 18 of Set 13 | bolu
# Processing Record 19 of Set 13 | praia
# Processing Record 20 of Set 13 | mporokoso
# Processing Record 21 of Set 13 | nalut
# Processing Record 22 of Set 13 | gondal
# Processing Record 23 of Set 13 | bayan
# Processing Record 24 of Set 13 | myanaung
# Processing Record 25 of Set 13 | waitati
# Processing Record 26 of Set 13 | soto la marina
# Processing Record 27 of Set 13 | kenai
# Processing Record 28 of Set 13 | mentok
# City not found. Skipping...
# Processing Record 29 of Set 13 | gunjur
# Processing Record 30 of Set 13 | alta
# Processing Record 31 of Set 13 | manyana
# Processing Record 32 of Set 13 | dabat
# Processing Record 33 of Set 13 | gravdal
# Processing Record 34 of Set 13 | vidim
# Processing Record 35 of Set 13 | yumen
# Processing Record 36 of Set 13 | eyl
# Processing Record 37 of Set 13 | sicamous
# Processing Record 38 of Set 13 | chara
# Processing Record 39 of Set 13 | plettenberg bay
# Processing Record 40 of Set 13 | zhezkazgan
# Processing Record 41 of Set 13 | matamoros
# Processing Record 42 of Set 13 | oktyabrskoye
# Processing Record 43 of Set 13 | bhopal
# Processing Record 44 of Set 13 | slave lake
# Processing Record 45 of Set 13 | tawang
# Processing Record 46 of Set 13 | kichera
# Processing Record 47 of Set 13 | beitbridge
# Processing Record 48 of Set 13 | kisangani
# Processing Record 49 of Set 13 | aksha
# Processing Record 50 of Set 13 | visnes
# Processing Record 1 of Set 14 | roma
# Processing Record 2 of Set 14 | alyangula
# Processing Record 3 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 4 of Set 14 | maguling
# Processing Record 5 of Set 14 | campbellsville
# Processing Record 6 of Set 14 | tacoronte
# Processing Record 7 of Set 14 | maragogi
# Processing Record 8 of Set 14 | we
# City not found. Skipping...
# Processing Record 9 of Set 14 | gizo
# Processing Record 10 of Set 14 | cancun
# Processing Record 11 of Set 14 | avera
# Processing Record 12 of Set 14 | zharkent
# Processing Record 13 of Set 14 | meulaboh
# Processing Record 14 of Set 14 | moose factory
# Processing Record 15 of Set 14 | roebourne
# Processing Record 16 of Set 14 | krasnoselkup
# Processing Record 17 of Set 14 | isangel
# Processing Record 18 of Set 14 | cairns
# Processing Record 19 of Set 14 | grindavik
# Processing Record 20 of Set 14 | tura
# Processing Record 21 of Set 14 | wajir
# Processing Record 22 of Set 14 | aban
# Processing Record 23 of Set 14 | arlit
# Processing Record 24 of Set 14 | bardiyah
# Processing Record 25 of Set 14 | santa cruz de la palma
# Processing Record 26 of Set 14 | tsienyane
# City not found. Skipping...
# Processing Record 27 of Set 14 | acarau
# Processing Record 28 of Set 14 | mirnyy
# Processing Record 29 of Set 14 | carlos antonio lopez
# Processing Record 30 of Set 14 | cascais
# Processing Record 31 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 14 | forestville
# Processing Record 33 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 34 of Set 14 | hongjiang
# Processing Record 35 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 36 of Set 14 | vao
# Processing Record 37 of Set 14 | sederot
# Processing Record 38 of Set 14 | sedalia
# Processing Record 39 of Set 14 | vestmannaeyjar
# Processing Record 40 of Set 14 | portland
# Processing Record 41 of Set 14 | nohar
# Processing Record 42 of Set 14 | corn island
# Processing Record 43 of Set 14 | fort saint james
# Processing Record 44 of Set 14 | opuwo
# Processing Record 45 of Set 14 | foumban
# Processing Record 46 of Set 14 | bosaso
# Processing Record 47 of Set 14 | danilov
# Processing Record 48 of Set 14 | jatai
# Processing Record 49 of Set 14 | gurupa
# Processing Record 50 of Set 14 | quatre cocos
# Processing Record 1 of Set 15 | lake charles
# Processing Record 2 of Set 15 | bari
# Processing Record 3 of Set 15 | dunedin
# Processing Record 4 of Set 15 | nikko
# Processing Record 5 of Set 15 | gamba
# Processing Record 6 of Set 15 | samdari
# Processing Record 7 of Set 15 | tamandare
# Processing Record 8 of Set 15 | qaqortoq
# Processing Record 9 of Set 15 | kudahuvadhoo
# Processing Record 10 of Set 15 | sarana
# Processing Record 11 of Set 15 | kahului
# Processing Record 12 of Set 15 | zolotinka
# City not found. Skipping...
# Processing Record 13 of Set 15 | faanui
# Processing Record 14 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 15 | galle
# Processing Record 16 of Set 15 | aiquile
# Processing Record 17 of Set 15 | eldikan
# City not found. Skipping...
# Processing Record 18 of Set 15 | bar harbor
# Processing Record 19 of Set 15 | jatiwangi
# Processing Record 20 of Set 15 | ures
# Processing Record 21 of Set 15 | shangqiu
# Processing Record 22 of Set 15 | spassk
# Processing Record 23 of Set 15 | natal
# Processing Record 24 of Set 15 | kasongo-lunda
# Processing Record 25 of Set 15 | katsuura
# Processing Record 26 of Set 15 | juneau
# Processing Record 27 of Set 15 | ilo
# Processing Record 28 of Set 15 | parvatipuram
# Processing Record 29 of Set 15 | tallahassee
# Processing Record 30 of Set 15 | sant
# Processing Record 31 of Set 15 | dicabisagan
# Processing Record 32 of Set 15 | sambava
# Processing Record 33 of Set 15 | wukari
# Processing Record 34 of Set 15 | virginia beach
# Processing Record 35 of Set 15 | kapit
# Processing Record 36 of Set 15 | rockhampton
# Processing Record 37 of Set 15 | bilibino
# Processing Record 38 of Set 15 | concarneau
# Processing Record 39 of Set 15 | black forest
# Processing Record 40 of Set 15 | monforte de lemos
# Processing Record 41 of Set 15 | bhag
# Processing Record 42 of Set 15 | kurchum
# Processing Record 43 of Set 15 | bashtanka
# Processing Record 44 of Set 15 | kismayo
# Processing Record 45 of Set 15 | erenhot
# Processing Record 46 of Set 15 | fereydun kenar
# Processing Record 47 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 48 of Set 15 | xining
# Processing Record 49 of Set 15 | orlik
# Processing Record 50 of Set 15 | yekaterinovka
# Processing Record 1 of Set 16 | buritizeiro
# Processing Record 2 of Set 16 | synya
# Processing Record 3 of Set 16 | boguchany
# Processing Record 4 of Set 16 | boca do acre
# Processing Record 5 of Set 16 | hobyo
# Processing Record 6 of Set 16 | tilichiki
# Processing Record 7 of Set 16 | labutta
# City not found. Skipping...
# Processing Record 8 of Set 16 | turayf
# Processing Record 9 of Set 16 | kirovskiy
# Processing Record 10 of Set 16 | soyo
# Processing Record 11 of Set 16 | half moon bay
# Processing Record 12 of Set 16 | kungurtug
# Processing Record 13 of Set 16 | larkana
# Processing Record 14 of Set 16 | esfarayen
# Processing Record 15 of Set 16 | champlin
# Processing Record 16 of Set 16 | cabatuan
# Processing Record 17 of Set 16 | wladyslawowo
# Processing Record 18 of Set 16 | roald
# Processing Record 19 of Set 16 | port shepstone
# Processing Record 20 of Set 16 | nishihara
# Processing Record 21 of Set 16 | port hedland
# Processing Record 22 of Set 16 | sao miguel do araguaia
# Processing Record 23 of Set 16 | mogadishu
# Processing Record 24 of Set 16 | ati
# Processing Record 25 of Set 16 | laguna de duero
# Processing Record 26 of Set 16 | usinsk
# Processing Record 27 of Set 16 | upata
# Processing Record 28 of Set 16 | veraval
# Processing Record 29 of Set 16 | sisophon
# Processing Record 30 of Set 16 | manado
# Processing Record 31 of Set 16 | prabumulih
# Processing Record 32 of Set 16 | sao joao da barra
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 721

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Sao Filipe      CV  14.8961  -24.4956     78.53        75           0
# 1   Nanortalik      GL  60.1432  -45.2371     33.37        96         100
# 2     Souillac      MU -20.5167   57.5167     75.36        73          40
# 3       Hasaki      JP  35.7333  140.8333     64.29        55          98
# 4        Bluff      NZ -46.6000  168.3333     53.13        65           6
# 5      Mosetse      BW -20.7500   26.6500     65.10        79          31
# 6        Pevek      RU  69.7008  170.3133      7.05        97          99
# 7      Rikitea      PF -23.1203 -134.9692     75.36        77           7
# 8    Ostrovnoy      RU  68.0531   39.5131     37.89        83         100
# 9  Kloulklubed      PW   7.0419  134.2556     88.30        73          34
#
#    Wind Speed Current Description
# 0        9.28           clear sky
# 1        2.26                snow
# 2       14.97    scattered clouds
# 3       16.40     overcast clouds
# 4       16.31           clear sky
# 5       19.30    scattered clouds
# 6        4.18     overcast clouds
# 7       15.19          light rain
# 8        5.21     overcast clouds
# 9       11.39    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label='City_ID')
